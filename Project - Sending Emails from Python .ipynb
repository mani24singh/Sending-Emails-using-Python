# %% [markdown]
# # Sending E-mails using python to friends & family members

# %% [markdown]
# ![sending%20emails.jpg](attachment:sending%20emails.jpg)

# %%
# !pip install emails

# %%
import emails

# %%
html_text = '''<p><span style="font-family: Georgia, serif;">Hey Avengers,</span></p>
<p><span style="font-family: Georgia, serif;">This is &nbsp;Tony Stark, i hope you guys &nbsp;are doing well on your vacations but enough of fun people... i am here to break your mood through this exciting news for emergeny. LOL...</span></p>
<p><span style="font-family: Georgia, serif;">Guys, we have been enough lucky that our old friend THANOS has survived and is back again with his noble thoughts of Ending the universe. And this time i think he has been inspired by the great Tony stark .......OHH i mean-ME.!!... and have bought some really cool and weird Gadgets &amp; techs around.&nbsp;</span></p>
<p><span style="font-family: Georgia, serif;">Friends i dont think it will be a good impact on my image that my assistants (LOL again) die on vacation. So come on buckle up, pack up ur Bags &amp; return ASAP.... <br>I dont want to KILL him ALONE again ,this time i want my assistance to get a chance too..(LOL thrice)......&nbsp;</span></p>
<p><span style="font-family: Georgia, serif;">Hoping to see you guys back alive.</span></p>
<p><span style="font-family: Georgia, serif;">Regards,</span></p>
<p><span style="font-family: Georgia, serif;">(Your Boss) LOL-4</span></p>
<p><span style="font-family: Georgia, serif;"><strong>TONY STARK</strong></span></p>
<p><span style="font-family: Georgia, serif;"><strong>Stark Industries</strong></span></p>
<p><span style="font-family: Georgia, serif;"><br></span></p>
<p><span style="font-family: Georgia, serif;">&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;</span></p>
<p><br></p>'''

message = emails.html(html= html_text,                                             #Adding a Text to Html 
                          subject="We Will Save the world Avengers",               #Subject of mail
                          mail_from=('Tony Stark','tonystark@avengers.com'))       #Email Sender Details

# %%
mail_via_python = message.send(to='dawawa2449@ddwfzp.com',               #Email recipient
                               smtp={'host': 'smtp.gmail.com',            #SMTP for gmail
                                     'timeout': 5,
                                     'port':587,
                                     'user':'tonystark@gmail.com',    #please insert your email in user
                                     'password':'tonytheironman',     #please insert your email-password here
                                     'tls':True})

# %%
mail_via_python.status_code        #if status code is 250, mail has been delivered successfuly
# Out:
# 250

# %%
def sendMail(email,name):                   #To generate a funtion for general mailing ease
    
    html_text = '''<p><span style="font-family: Georgia, serif;">Hey Avenger('''+ name +'''),</span></p>
                <p><span style="font-family: Georgia, serif;">This is &nbsp;Tony Stark, i hope you guys &nbsp;are doing well on your vacations but enough of fun people... i am here to break your mood through this exciting news for emergeny. LOL...</span></p>
                <p><span style="font-family: Georgia, serif;">Guys, we have been enough lucky that our old friend THANOS has survived and is back again with his noble thoughts of Ending the universe. And this time i think he has been inspired by the great Tony stark .......OHH i mean-ME.!!... and have bought some really cool and weird Gadgets &amp; techs around.&nbsp;</span></p>
                <p><span style="font-family: Georgia, serif;">Friends i dont think it will be a good impact on my image that my assistants (LOL again) die on vacation. So come on buckle up, pack up ur Bags &amp; return ASAP.... <br>I dont want to KILL him ALONE again ,this time i want my assistance to get a chance too..(LOL thrice)......&nbsp;</span></p>
                <p><span style="font-family: Georgia, serif;">Hoping to see you guys back alive.</span></p>
                <p><span style="font-family: Georgia, serif;">Regards,</span></p>
                <p><span style="font-family: Georgia, serif;">(Your Boss) LOL-4</span></p>
                <p><span style="font-family: Georgia, serif;"><strong>TONY STARK</strong></span></p>
                <p><span style="font-family: Georgia, serif;"><strong>Stark Industries</strong></span></p>
                <p><span style="font-family: Georgia, serif;"><br></span></p>
                <p><span style="font-family: Georgia, serif;">&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;</span></p>
                <p><br></p>'''

    subject = "Hey Avenger-"+ name +",THANOS is Back"                                  #Add a subject with name 
    message = emails.html(html= html_text,                                             #Adding Text to Html
                          subject=subject,                                             #Subject location name
                          mail_from=('Tony Stark','tonystark@avengers.com'))           #Sender Details

    mail_via_python = message.send(to=email, 
                               smtp={'host': 'smtp.gmail.com',            #SMTP for gmail
                                     'timeout': 5,
                                     'port':587,
                                     'user':'tonystark@gmail.com',       #please insert your email in user
                                     'password':'tonytheironman',        #please insert your email-password here
                                     'tls':True})         
    return mail_via_python.status_code

# %%
sendMail("dawawa2449@ddwfzp.com","HULK")   #generalised common mail to send multiple recipient on their mail address
# Out:
# 250

# %%
sendMail("lijeyax397@684hh.com","THOR")
# Out:
# 250

# %%
sendMail("pafek26415@ddwfzp.com","Captain")
# Out:
# 250

# %% [markdown]
# ![email%20sending.jpg](attachment:email%20sending.jpg)
